# %% [markdown]
# # Deep Learning
#
# SVM , RANDOM FOREST, ..
#
# 1. Deep Learning
#
# - GPU -> core가 많이 할당 해서 픽셀별로 빠른 처리
#
# * Geoffrey Hinton -> Back progagation , Yann LeCun, Andrew Ng(Topic modelng)-> LDA, Yoshua Bengio
# Coursera -> Deep learning
# CS231n -> 2-3 번 째에 back propagation 설명 있음
#
# - Face Detection & Recognition
# - Image captioning (yunjey/show-attena and tell), DenseCap: Fully convolutional Localization Networks for Dense ..
#
# - 네이버 -> 웹툰 자동 색칠 ( 그 웹툰 풍으로 색칠 )
# - Deepfakes- 움직이는 동영상, 음성
# - Medical Analysis
#
# - Machine Translation
# - Sentiment Analysis (감정 분석)
# - Recommender System (추천 시스템) : 마케팅, 경영

# %% [markdown]
# 2. Perceptron
#
# - Human Brain and Neral Network
#
# 1) Single Layer Perceptron
#     - Inputs
#     - Outputs
#     - Weights
#     - Bias
#
# 2) Multi Layer Perceptron
#     - XOR Gate

# %% [markdown]
# 3. Neural Network
#     - Hidden layer
#
#     - A Neural Network playgrond:
#      https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.49446&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false
#
# 4. Forward Propagation
#     - a: j 번째 노드의 i번째 activation function
#     - theta: layer의 가중치
#
#     - Activatgion Functions
#
#     - MNIST Example -> 픽셀 단위로 나눠서 숫자 인식
#         ( prediction - target )^2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Backpropagation
#
# - Gradient Descent : 경사가 낮으면 내려가는 형식
#     - learning rate : (0.01, 0.0001, ... empirical 최적의 값 찾는 것)
#         - 너무 값을 크게 주면 local minimum에 빠지는 문제점이 있음 <-> global minimum
#
# - chain rule

# %% [markdown]
# - Deep Learning Framework : PYTORCH, TeonsorFlow, Keras (가장 언어가 쉬움. 케라스가 텐서플로우에 합병)

# %% [markdown]
# Networks for Visual Recognition
# Machine Learning -Stanford University | Coursera
# Attention and Augmented Recurrent Neural Networks —Distill
# Alec Radford's animations for optimization
# http://www.denizyuret.com/2015/03/alec-radfords-animations-for.html
# A Neural Network Playground
# DenseCap: Fully Convolutional Localization Networks for Dense Captioning

# %% [markdown]
# # PyTorch
#
# - GPU 연산

# %%
import torch
import numpy as np

# %%
torch.cuda.is_available()
# Out:
# False

# %%
a = torch.FloatTensor([[2,3,4,5]])

a # float 형태로 띄는 것
# Out:
# tensor([[2., 3., 4., 5.]])

# %%
b= np.array([[3,4,5,6]])

b.reshape(2,2)
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
a.view(2,2)

a.view(2,-1) # -1 자동으로 나머지 사이즈 할당해주는 것
# Out:
# tensor([[2., 3.],
#         [4., 5.]])

# %%
a.view(2,-1).flatten()
# Out:
# tensor([2., 3., 4., 5.])

# %%
a.unsqueeze(1).shape # 1이 하나 더 껴주게 되는 것
# Out:
# torch.Size([1, 1, 4])

# %%
a.shape
# Out:
# torch.Size([1, 4])

# %%
a.unsqueeze(1).squeeze(0).shape
# Out:
# torch.Size([1, 4])

# %%
a.size(0) # 첫번째 dimension의 크기가 뭐인지 확인하는 것
# Out:
# 1

# %%
device= torch.device('cuda:0') # gpu어떤거사용할지 0

# %%
# GPU -> 컴퓨터마다 있는 컴터 있고 없는 컴터 있고
# Cuda -> GPU 도와주는 라이브러리 
a=a.to(device)
a
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-31-b6425b28c3f6> in <module>
# ----> 1 a=a.to(device)
#       2 a
#
# ~\Anaconda3\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     160         raise RuntimeError(
#     161             "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 162     _check_driver()
#     163     torch._C._cuda_init()
#     164     _cudart = _load_cudart()
#
# ~\Anaconda3\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      80 Found no NVIDIA driver on your system. Please check that you
#      81 have an NVIDIA GPU and installed a driver from
# ---> 82 http://www.nvidia.com/Download/index.aspx""")
#      83         else:
#      84             # TODO: directly link to the alternative bin that needs install
#
# AssertionError:
# Found no NVIDIA driver on your system. Please check that you
# ...

# %%
# !nvidia-smi # 메모리 확인 - out of memory
# Out:
# 'nvidia-smi'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
a= torch.cuda.FloatTensor(1024,1024,256) # 1024* 1024= 1 mb * 256 = 256 mb
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-33-e31d95655176> in <module>
# ----> 1 a= torch.cuda.FloatTensor(1024,1024,256) # 1024* 1024= 1 mb * 256 = 256 mb
#
# ~\Anaconda3\lib\site-packages\torch\cuda\__init__.py in _lazy_init()
#     160         raise RuntimeError(
#     161             "Cannot re-initialize CUDA in forked subprocess. " + msg)
# --> 162     _check_driver()
#     163     torch._C._cuda_init()
#     164     _cudart = _load_cudart()
#
# ~\Anaconda3\lib\site-packages\torch\cuda\__init__.py in _check_driver()
#      80 Found no NVIDIA driver on your system. Please check that you
#      81 have an NVIDIA GPU and installed a driver from
# ---> 82 http://www.nvidia.com/Download/index.aspx""")
#      83         else:
#      84             # TODO: directly link to the alternative bin that needs install
#
# AssertionError:
# ...

# %%
# torch.nn
# https://pytorch.org/docs/stable/nn.html

# %% [markdown]
# - Training Model
#
# * Epochs : 모든 데이터에 대해서 n번 다 학습해본 것 : n번 Epochs
# * Epochs -> 순서를 바꿔주면서 학습을 한다.
